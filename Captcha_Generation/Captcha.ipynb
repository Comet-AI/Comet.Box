# %% [markdown]
# ## Exploratory Analysis
# To begin this exploratory analysis, first use `matplotlib` to import libraries and define functions for plotting the data. Depending on the data, not all plots will be made.

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/samples/samples/yd38e.png
# /kaggle/input/samples/samples/7gmf3.png
# /kaggle/input/samples/samples/dgcm4.jpg
# /kaggle/input/samples/samples/nb267.png
# /kaggle/input/samples/samples/wce5n.png
# /kaggle/input/samples/samples/n7meb.png
# /kaggle/input/samples/samples/nfcwy.png
# /kaggle/input/samples/samples/d22bd.png
# /kaggle/input/samples/samples/8684m.png
# /kaggle/input/samples/samples/n373n.png
# /kaggle/input/samples/samples/8n56m.png
# /kaggle/input/samples/samples/8fexn.png
# /kaggle/input/samples/samples/g3ex3.png
# /kaggle/input/samples/samples/53mn8.png
# /kaggle/input/samples/samples/mpmy5.png
# /kaggle/input/samples/samples/p2dw7.png
# /kaggle/input/samples/samples/wxcn8.png
# /kaggle/input/samples/samples/c8fxy.png
# /kaggle/input/samples/samples/cfn53.png
# /kaggle/input/samples/samples/43p5d.png
# /kaggle/input/samples/samples/3d7bd.png
# /kaggle/input/samples/samples/2356g.png
# /kaggle/input/samples/samples/fg38b.png
# /kaggle/input/samples/samples/p57fn.png
# /kaggle/input/samples/samples/57b27.png
# /kaggle/input/samples/samples/5g5e5.png
# /kaggle/input/samples/samples/6mn8n.png
# /kaggle/input/samples/samples/wb3ed.png
# /kaggle/input/samples/samples/c353e.png
# /kaggle/input/samples/samples/6fg8c.png
# /kaggle/input/samples/samples/cwgyx.png
# /kaggle/input/samples/samples/x6b5m.png
# /kaggle/input/samples/samples/deneb.png
# /kaggle/input/samples/samples/nxcmn.png
# /kaggle/input/samples/samples/enpw2.png
# /kaggle/input/samples/samples/fy2nd.png
# /kaggle/input/samples/samples/fywb8.png
# /kaggle/input/samples/samples/ndme7.png
# /kaggle/input/samples/samples/m5ym2.png
# /kaggle/input/samples/samples/n336e.png
# /kaggle/input/samples/samples/f5e5e.png
# /kaggle/input/samples/samples/6b46g.png
# /kaggle/input/samples/samples/xe8xm.png
# /kaggle/input/samples/samples/y7mnm.png
# /kaggle/input/samples/samples/2cg58.png
# /kaggle/input/samples/samples/n5n8b.png
# /kaggle/input/samples/samples/w2e87.png
# /kaggle/input/samples/samples/y3c58.png
# /kaggle/input/samples/samples/47m2b.png
# /kaggle/input/samples/samples/ncfgb.png
# /kaggle/input/samples/samples/57gnx.png
# /kaggle/input/samples/samples/w6ny4.jpg
# /kaggle/input/samples/samples/7fde7.png
# /kaggle/input/samples/samples/428b6.png
# /kaggle/input/samples/samples/b5dn4.png
# /kaggle/input/samples/samples/gf2g4.png
# /kaggle/input/samples/samples/x7547.png
# /kaggle/input/samples/samples/pm47f.png
# /kaggle/input/samples/samples/d378n.png
# /kaggle/input/samples/samples/xc68n.png
# /kaggle/input/samples/samples/c4bgd.png
# /kaggle/input/samples/samples/bx5ed.jpg
# /kaggle/input/samples/samples/p8wwf.png
# /kaggle/input/samples/samples/ycnfc.png
# /kaggle/input/samples/samples/m67b3.png
# /kaggle/input/samples/samples/76nxn.png
# /kaggle/input/samples/samples/gm7n8.png
# /kaggle/input/samples/samples/gp22x.png
# /kaggle/input/samples/samples/feyc8.png
# /kaggle/input/samples/samples/d7nn3.png
# /kaggle/input/samples/samples/defyx.png
# /kaggle/input/samples/samples/gy8xb.png
# /kaggle/input/samples/samples/fp762.png
# /kaggle/input/samples/samples/5mcy7.png
# /kaggle/input/samples/samples/8c23f.png
# /kaggle/input/samples/samples/28348.png
# /kaggle/input/samples/samples/p7fyp.png
# /kaggle/input/samples/samples/d666m.png
# /kaggle/input/samples/samples/nf7bn.png
# /kaggle/input/samples/samples/npxb7.png
# /kaggle/input/samples/samples/47e4p.png
# /kaggle/input/samples/samples/b5pnn.png
# /kaggle/input/samples/samples/f858x.png
# /kaggle/input/samples/samples/cc845.png
# /kaggle/input/samples/samples/c3n8x.png
# /kaggle/input/samples/samples/8y6b3.png
# /kaggle/input/samples/samples/2nbc5.jpg
# /kaggle/input/samples/samples/gpnxn.png
# /kaggle/input/samples/samples/x4f7g.png
# /kaggle/input/samples/samples/gny6b.png
# /kaggle/input/samples/samples/pg2pm.png
# /kaggle/input/samples/samples/bny4w.png
# /kaggle/input/samples/samples/nn6mg.png
# /kaggle/input/samples/samples/8n65n.png
# /kaggle/input/samples/samples/ywn6f.png
# /kaggle/input/samples/samples/nf2n8.png
# /kaggle/input/samples/samples/xce8d.png
# /kaggle/input/samples/samples/pwebm.png
# /kaggle/input/samples/samples/m3wfw.png
# /kaggle/input/samples/samples/ndyfe.png
# /kaggle/input/samples/samples/fnbfw.png
# /kaggle/input/samples/samples/cd6p4.png
# /kaggle/input/samples/samples/6bxwg.png
# /kaggle/input/samples/samples/c482b.png
# /kaggle/input/samples/samples/bw6n6.png
# /kaggle/input/samples/samples/556wd.png
# /kaggle/input/samples/samples/fdpgd.png
# /kaggle/input/samples/samples/85622.png
# /kaggle/input/samples/samples/n3xfg.jpg
# /kaggle/input/samples/samples/mgw3n.png
# /kaggle/input/samples/samples/y4ec2.png
# /kaggle/input/samples/samples/bd3b7.png
# /kaggle/input/samples/samples/gpxng.png
# /kaggle/input/samples/samples/n7g4f.png
# /kaggle/input/samples/samples/n4wwn.png
# /kaggle/input/samples/samples/myc3c.png
# /kaggle/input/samples/samples/bdbb3.png
# /kaggle/input/samples/samples/xyyyw.png
# /kaggle/input/samples/samples/b5fm7.png
# /kaggle/input/samples/samples/ybfx6.png
# /kaggle/input/samples/samples/y866y.png
# /kaggle/input/samples/samples/7f8b3.png
# /kaggle/input/samples/samples/33p4e.png
# /kaggle/input/samples/samples/gdng3.png
# /kaggle/input/samples/samples/34pcn.png
# /kaggle/input/samples/samples/6ge3p.png
# /kaggle/input/samples/samples/m22e3.png
# /kaggle/input/samples/samples/67dey.png
# /kaggle/input/samples/samples/8n5pn.png
# /kaggle/input/samples/samples/e8e5e.png
# /kaggle/input/samples/samples/neecd.png
# /kaggle/input/samples/samples/5fyem.png
# /kaggle/input/samples/samples/xbcbx.png
# /kaggle/input/samples/samples/53wp3.png
# /kaggle/input/samples/samples/7p852.png
# /kaggle/input/samples/samples/2bg48.png
# /kaggle/input/samples/samples/n5cm7.png
# /kaggle/input/samples/samples/nny5e.png
# /kaggle/input/samples/samples/e8dxn.png
# /kaggle/input/samples/samples/gn2d3.png
# /kaggle/input/samples/samples/yxd7m.png
# /kaggle/input/samples/samples/8eggg.png
# /kaggle/input/samples/samples/x362g.png
# /kaggle/input/samples/samples/d7c5x.png
# /kaggle/input/samples/samples/3ebnn.png
# /kaggle/input/samples/samples/dfnx4.png
# /kaggle/input/samples/samples/c7gb3.png
# /kaggle/input/samples/samples/6825y.png
# /kaggle/input/samples/samples/g888x.png
# /kaggle/input/samples/samples/xymfn.png
# /kaggle/input/samples/samples/ffpxf.png
# /kaggle/input/samples/samples/efg72.png
# /kaggle/input/samples/samples/gn2xy.png
# /kaggle/input/samples/samples/y48c3.png
# /kaggle/input/samples/samples/yw667.png
# /kaggle/input/samples/samples/fpw76.png
# /kaggle/input/samples/samples/7mgmf.png
# /kaggle/input/samples/samples/34b84.png
# /kaggle/input/samples/samples/mfb3x.png
# /kaggle/input/samples/samples/x4gg5.png
# /kaggle/input/samples/samples/ebcbx.png
# /kaggle/input/samples/samples/ny8np.png
# /kaggle/input/samples/samples/6fgdw.png
# /kaggle/input/samples/samples/gwnm6.png
# /kaggle/input/samples/samples/7634y.png
# /kaggle/input/samples/samples/3bx86.png
# /kaggle/input/samples/samples/4743p.png
# /kaggle/input/samples/samples/e7x45.png
# /kaggle/input/samples/samples/dyp7n.png
# /kaggle/input/samples/samples/ncww7.png
# /kaggle/input/samples/samples/g247w.png
# /kaggle/input/samples/samples/nm46n.png
# /kaggle/input/samples/samples/5pm6b.png
# /kaggle/input/samples/samples/nfndw.png
# /kaggle/input/samples/samples/n6xc5.png
# /kaggle/input/samples/samples/56c34.png
# /kaggle/input/samples/samples/wmpmp.png
# /kaggle/input/samples/samples/268g2.png
# /kaggle/input/samples/samples/gfbx6.png
# /kaggle/input/samples/samples/56m6y.png
# /kaggle/input/samples/samples/3b4we.png
# /kaggle/input/samples/samples/244e2.png
# /kaggle/input/samples/samples/f4fn2.png
# /kaggle/input/samples/samples/2wc38.png
# /kaggle/input/samples/samples/yeyn4.png
# /kaggle/input/samples/samples/mwdf6.png
# /kaggle/input/samples/samples/2mg87.png
# /kaggle/input/samples/samples/4cfw8.png
# /kaggle/input/samples/samples/dmw8n.png
# /kaggle/input/samples/samples/fw3b2.png
# /kaggle/input/samples/samples/ny3dw.png
# /kaggle/input/samples/samples/d4n82.png
# /kaggle/input/samples/samples/4433m.png
# /kaggle/input/samples/samples/8b735.png
# /kaggle/input/samples/samples/n7ff2.png
# /kaggle/input/samples/samples/3nnpw.png
# /kaggle/input/samples/samples/d3ycn.png
# /kaggle/input/samples/samples/pw5nc.png
# /kaggle/input/samples/samples/wg625.png
# /kaggle/input/samples/samples/fbp2c.png
# /kaggle/input/samples/samples/2yggg.png
# /kaggle/input/samples/samples/5xd2e.png
# /kaggle/input/samples/samples/6xen4.png
# /kaggle/input/samples/samples/dcnp8.png
# /kaggle/input/samples/samples/664nf.png
# /kaggle/input/samples/samples/fc6xb.png
# /kaggle/input/samples/samples/7wn74.png
# /kaggle/input/samples/samples/y53c2.png
# /kaggle/input/samples/samples/pme86.png
# /kaggle/input/samples/samples/bn5mw.png
# /kaggle/input/samples/samples/g6n7x.png
# /kaggle/input/samples/samples/6dd2y.png
# /kaggle/input/samples/samples/658xe.png
# /kaggle/input/samples/samples/5mf7c.png
# /kaggle/input/samples/samples/wd2gb.png
# /kaggle/input/samples/samples/y4n6m.png
# /kaggle/input/samples/samples/573d8.png
# /kaggle/input/samples/samples/nbcgb.png
# /kaggle/input/samples/samples/2pfpn.png
# /kaggle/input/samples/samples/nwg2m.png
# /kaggle/input/samples/samples/gw468.png
# /kaggle/input/samples/samples/75pfw.png
# /kaggle/input/samples/samples/mdyp7.png
# /kaggle/input/samples/samples/byfgn.png
# /kaggle/input/samples/samples/2p2y8.png
# /kaggle/input/samples/samples/y7d75.png
# /kaggle/input/samples/samples/325fb.png
# /kaggle/input/samples/samples/pmd3w.png
# /kaggle/input/samples/samples/nfd8g.png
# /kaggle/input/samples/samples/ee8fg.png
# /kaggle/input/samples/samples/n4xx5.png
# /kaggle/input/samples/samples/3ny45.png
# /kaggle/input/samples/samples/5mgn4.png
# /kaggle/input/samples/samples/2mpnn.png
# /kaggle/input/samples/samples/d3c7y.png
# /kaggle/input/samples/samples/f74x3.png
# /kaggle/input/samples/samples/6wg4n.png
# /kaggle/input/samples/samples/enn7n.png
# /kaggle/input/samples/samples/gng6e.png
# /kaggle/input/samples/samples/pyefb.png
# /kaggle/input/samples/samples/dbfen.png
# /kaggle/input/samples/samples/3n3cf.png
# /kaggle/input/samples/samples/bnc2f.png
# /kaggle/input/samples/samples/mmfm6.png
# /kaggle/input/samples/samples/6f857.png
# /kaggle/input/samples/samples/e25xg.png
# /kaggle/input/samples/samples/n5x2n.png
# /kaggle/input/samples/samples/7y2x4.png
# /kaggle/input/samples/samples/n4b4m.png
# /kaggle/input/samples/samples/5npdn.png
# /kaggle/input/samples/samples/fcne6.png
# /kaggle/input/samples/samples/6mygb.png
# /kaggle/input/samples/samples/32dnn.png
# /kaggle/input/samples/samples/g8gnd.png
# /kaggle/input/samples/samples/pm363.png
# /kaggle/input/samples/samples/nmy2x.png
# /kaggle/input/samples/samples/dw6mn.png
# /kaggle/input/samples/samples/6wnyc.png
# /kaggle/input/samples/samples/g7gnf.png
# /kaggle/input/samples/samples/8bbm4.png
# /kaggle/input/samples/samples/p6mn8.png
# /kaggle/input/samples/samples/gecmf.png
# /kaggle/input/samples/samples/x458w.png
# /kaggle/input/samples/samples/edwny.png
# /kaggle/input/samples/samples/fgb36.jpg
# /kaggle/input/samples/samples/2x7bm.png
# /kaggle/input/samples/samples/b55d6.png
# /kaggle/input/samples/samples/n2gmg.png
# /kaggle/input/samples/samples/m23bp.png
# /kaggle/input/samples/samples/7g3nf.png
# /kaggle/input/samples/samples/bcwnn.png
# /kaggle/input/samples/samples/xcf88.png
# /kaggle/input/samples/samples/3ebpw.png
# /kaggle/input/samples/samples/cfc2y.png
# /kaggle/input/samples/samples/pxdwp.png
# /kaggle/input/samples/samples/b5nmm.png
# /kaggle/input/samples/samples/wbncw.png
# /kaggle/input/samples/samples/678w3.png
# /kaggle/input/samples/samples/f2fge.png
# /kaggle/input/samples/samples/6ng6n.png
# /kaggle/input/samples/samples/c6we6.png
# /kaggle/input/samples/samples/e2d66.png
# /kaggle/input/samples/samples/x775w.png
# /kaggle/input/samples/samples/c2pg6.png
# /kaggle/input/samples/samples/pcm7f.png
# /kaggle/input/samples/samples/8n34n.png
# /kaggle/input/samples/samples/474ff.png
# /kaggle/input/samples/samples/23mdg.png
# /kaggle/input/samples/samples/3ym7f.png
# /kaggle/input/samples/samples/e3ndn.png
# /kaggle/input/samples/samples/y2436.png
# /kaggle/input/samples/samples/bgb48.png
# /kaggle/input/samples/samples/82fx2.png
# /kaggle/input/samples/samples/gfp54.png
# /kaggle/input/samples/samples/4ynf3.png
# /kaggle/input/samples/samples/33f7m.png
# /kaggle/input/samples/samples/42xpy.png
# /kaggle/input/samples/samples/w48cw.png
# /kaggle/input/samples/samples/pym7p.png
# /kaggle/input/samples/samples/5ywwf.png
# /kaggle/input/samples/samples/nnn57.png
# /kaggle/input/samples/samples/7dyww.png
# /kaggle/input/samples/samples/exycn.png
# /kaggle/input/samples/samples/5x5nx.png
# /kaggle/input/samples/samples/mbf58.png
# /kaggle/input/samples/samples/78dw6.jpg
# /kaggle/input/samples/samples/mmg2m.png
# /kaggle/input/samples/samples/xyncc.png
# /kaggle/input/samples/samples/xw465.png
# /kaggle/input/samples/samples/7dxbd.png
# /kaggle/input/samples/samples/ydd3g.png
# /kaggle/input/samples/samples/x277e.png
# /kaggle/input/samples/samples/c4527.png
# /kaggle/input/samples/samples/b4y5x.png
# /kaggle/input/samples/samples/e46pd.png
# /kaggle/input/samples/samples/gbxyy.png
# /kaggle/input/samples/samples/wwmn6.png
# /kaggle/input/samples/samples/5mnpd.png
# /kaggle/input/samples/samples/8gmc4.png
# /kaggle/input/samples/samples/8gf7n.png
# /kaggle/input/samples/samples/n3bm6.png
# /kaggle/input/samples/samples/87d4c.png
# /kaggle/input/samples/samples/x5f54.png
# /kaggle/input/samples/samples/6ecbn.png
# /kaggle/input/samples/samples/37d52.png
# /kaggle/input/samples/samples/ncw4g.png
# /kaggle/input/samples/samples/w4nfx.png
# /kaggle/input/samples/samples/ewcf5.png
# /kaggle/input/samples/samples/fcmem.png
# /kaggle/input/samples/samples/ng756.png
# /kaggle/input/samples/samples/y5g87.png
# /kaggle/input/samples/samples/ydg8n.png
# /kaggle/input/samples/samples/68wfd.png
# /kaggle/input/samples/samples/574d7.png
# /kaggle/input/samples/samples/m2576.png
# /kaggle/input/samples/samples/7d44m.png
# /kaggle/input/samples/samples/mcg43.png
# /kaggle/input/samples/samples/fwxdp.png
# /kaggle/input/samples/samples/8y63f.png
# /kaggle/input/samples/samples/7w67m.png
# /kaggle/input/samples/samples/ng6yp.png
# /kaggle/input/samples/samples/7m8px.png
# /kaggle/input/samples/samples/be6np.png
# /kaggle/input/samples/samples/b2nen.png
# /kaggle/input/samples/samples/mmg38.png
# /kaggle/input/samples/samples/677g3.png
# /kaggle/input/samples/samples/pnnwy.png
# /kaggle/input/samples/samples/8npe3.png
# /kaggle/input/samples/samples/2nx38.png
# /kaggle/input/samples/samples/5bg8f.png
# /kaggle/input/samples/samples/6p2ge.png
# /kaggle/input/samples/samples/8npd5.png
# /kaggle/input/samples/samples/5nggg.png
# /kaggle/input/samples/samples/5n3w4.png
# /kaggle/input/samples/samples/mfc35.png
# /kaggle/input/samples/samples/b4ncn.png
# /kaggle/input/samples/samples/4gb3f.png
# /kaggle/input/samples/samples/8np22.png
# /kaggle/input/samples/samples/ygce8.jpg
# /kaggle/input/samples/samples/bdg84.png
# /kaggle/input/samples/samples/mbp2y.png
# /kaggle/input/samples/samples/bf52c.png
# /kaggle/input/samples/samples/gmmne.jpg
# /kaggle/input/samples/samples/8pfxx.png
# /kaggle/input/samples/samples/62fgn.jpg
# /kaggle/input/samples/samples/76n7p.png
# /kaggle/input/samples/samples/84w7x.png
# /kaggle/input/samples/samples/76y6f.png
# /kaggle/input/samples/samples/c55c6.png
# /kaggle/input/samples/samples/445cc.png
# /kaggle/input/samples/samples/243mm.png
# /kaggle/input/samples/samples/662bw.png
# /kaggle/input/samples/samples/bw44w.png
# /kaggle/input/samples/samples/6cm6m.png
# /kaggle/input/samples/samples/p8ngx.png
# /kaggle/input/samples/samples/3c7de.jpg
# /kaggle/input/samples/samples/4exnn.png
# /kaggle/input/samples/samples/ny3nn.png
# /kaggle/input/samples/samples/efx34.png
# /kaggle/input/samples/samples/x37bf.png
# /kaggle/input/samples/samples/pgwnp.png
# /kaggle/input/samples/samples/ffnxn.png
# /kaggle/input/samples/samples/3ygde.png
# /kaggle/input/samples/samples/m75bf.png
# /kaggle/input/samples/samples/pcede.png
# /kaggle/input/samples/samples/w4x2m.png
# /kaggle/input/samples/samples/pcpg6.png
# /kaggle/input/samples/samples/md344.png
# /kaggle/input/samples/samples/xf4p4.png
# /kaggle/input/samples/samples/73mnx.png
# /kaggle/input/samples/samples/fyfbn.png
# /kaggle/input/samples/samples/cwdnx.png
# /kaggle/input/samples/samples/gwn53.png
# /kaggle/input/samples/samples/gnf85.png
# /kaggle/input/samples/samples/x7746.png
# /kaggle/input/samples/samples/537nf.png
# /kaggle/input/samples/samples/mcc2x.png
# /kaggle/input/samples/samples/f6ne5.png
# /kaggle/input/samples/samples/6e2dg.png
# /kaggle/input/samples/samples/3w2bw.png
# /kaggle/input/samples/samples/3n7mx.png
# /kaggle/input/samples/samples/nc4yg.png
# /kaggle/input/samples/samples/n7enn.png
# /kaggle/input/samples/samples/fc2ff.png
# /kaggle/input/samples/samples/gnbde.png
# /kaggle/input/samples/samples/e84n2.png
# /kaggle/input/samples/samples/4n3mn.png
# /kaggle/input/samples/samples/373gb.png
# /kaggle/input/samples/samples/bw5nf.png
# /kaggle/input/samples/samples/g7fmc.png
# /kaggle/input/samples/samples/mggce.png
# /kaggle/input/samples/samples/3xcgg.png
# /kaggle/input/samples/samples/d22y5.png
# /kaggle/input/samples/samples/85pew.jpg
# /kaggle/input/samples/samples/d66cn.png
# /kaggle/input/samples/samples/pgg3n.png
# /kaggle/input/samples/samples/m4fd8.png
# /kaggle/input/samples/samples/38n57.png
# /kaggle/input/samples/samples/3ye2e.png
# /kaggle/input/samples/samples/gm6nn.png
# /kaggle/input/samples/samples/8n5p3.png
# /kaggle/input/samples/samples/dnxdp.png
# /kaggle/input/samples/samples/77387.png
# /kaggle/input/samples/samples/88bgx.png
# /kaggle/input/samples/samples/52447.png
# /kaggle/input/samples/samples/6wb76.png
# /kaggle/input/samples/samples/d2ycw.png
# /kaggle/input/samples/samples/6xxdx.png
# /kaggle/input/samples/samples/nybcx.png
# /kaggle/input/samples/samples/x3deb.png
# /kaggle/input/samples/samples/dd5w5.png
# /kaggle/input/samples/samples/44c22.png
# /kaggle/input/samples/samples/44ype.png
# /kaggle/input/samples/samples/25m6p.png
# /kaggle/input/samples/samples/cnex4.png
# /kaggle/input/samples/samples/ddmyg.png
# /kaggle/input/samples/samples/m2nf4.png
# /kaggle/input/samples/samples/mxnw4.png
# /kaggle/input/samples/samples/5n245.png
# /kaggle/input/samples/samples/8n62n.png
# /kaggle/input/samples/samples/wm746.png
# /kaggle/input/samples/samples/4m2w5.png
# /kaggle/input/samples/samples/5325m.png
# /kaggle/input/samples/samples/nbwpn.png
# /kaggle/input/samples/samples/f8f8g.png
# /kaggle/input/samples/samples/byc82.png
# /kaggle/input/samples/samples/mg5nn.png
# /kaggle/input/samples/samples/y5w28.png
# /kaggle/input/samples/samples/nw5b2.png
# /kaggle/input/samples/samples/675p3.png
# /kaggle/input/samples/samples/4n2yg.png
# /kaggle/input/samples/samples/mddgb.png
# /kaggle/input/samples/samples/62nb3.png
# /kaggle/input/samples/samples/dbpcd.png
# /kaggle/input/samples/samples/ecd4w.png
# /kaggle/input/samples/samples/gnbn4.png
# /kaggle/input/samples/samples/e6b7y.png
# /kaggle/input/samples/samples/25egp.png
# /kaggle/input/samples/samples/2w4y7.png
# /kaggle/input/samples/samples/fcey3.png
# /kaggle/input/samples/samples/pbpgc.png
# /kaggle/input/samples/samples/6g45w.png
# /kaggle/input/samples/samples/pp87n.png
# /kaggle/input/samples/samples/dw8d3.png
# /kaggle/input/samples/samples/pyf65.png
# /kaggle/input/samples/samples/b685n.png
# /kaggle/input/samples/samples/2nbcx.png
# /kaggle/input/samples/samples/ddcne.png
# /kaggle/input/samples/samples/pnmxf.png
# /kaggle/input/samples/samples/3fbxd.png
# /kaggle/input/samples/samples/84py4.jpg
# /kaggle/input/samples/samples/pdw38.png
# /kaggle/input/samples/samples/x76mn.png
# /kaggle/input/samples/samples/wgnwp.png
# /kaggle/input/samples/samples/cfw6e.png
# /kaggle/input/samples/samples/nd5wg.png
# /kaggle/input/samples/samples/728n8.png
# /kaggle/input/samples/samples/6b4w6.png
# /kaggle/input/samples/samples/7bwm2.png
# /kaggle/input/samples/samples/6m5eg.png
# /kaggle/input/samples/samples/d75b5.png
# /kaggle/input/samples/samples/dd764.png
# /kaggle/input/samples/samples/7wnpm.png
# /kaggle/input/samples/samples/4ycex.png
# /kaggle/input/samples/samples/mye68.png
# /kaggle/input/samples/samples/gc277.png
# /kaggle/input/samples/samples/ef4np.png
# /kaggle/input/samples/samples/m4g8g.png
# /kaggle/input/samples/samples/fp382.png
# /kaggle/input/samples/samples/eng53.png
# /kaggle/input/samples/samples/3bd8f.png
# /kaggle/input/samples/samples/m74dm.png
# /kaggle/input/samples/samples/n8pfe.png
# /kaggle/input/samples/samples/mcyfx.png
# /kaggle/input/samples/samples/w7e6m.png
# /kaggle/input/samples/samples/8ne4g.png
# /kaggle/input/samples/samples/y2ye8.png
# /kaggle/input/samples/samples/n8wxm.jpg
# /kaggle/input/samples/samples/eppg3.png
# /kaggle/input/samples/samples/men4f.png
# /kaggle/input/samples/samples/dmx8p.png
# /kaggle/input/samples/samples/cnmnn.png
# /kaggle/input/samples/samples/8w754.png
# /kaggle/input/samples/samples/bp6mw.png
# /kaggle/input/samples/samples/5xwcg.png
# /kaggle/input/samples/samples/nfcb5.png
# /kaggle/input/samples/samples/44fyb.png
# /kaggle/input/samples/samples/7gp47.png
# /kaggle/input/samples/samples/6bdn5.png
# /kaggle/input/samples/samples/8w875.png
# /kaggle/input/samples/samples/c86md.png
# /kaggle/input/samples/samples/e667x.png
# /kaggle/input/samples/samples/yx2d4.png
# /kaggle/input/samples/samples/e7nx4.png
# /kaggle/input/samples/samples/gcx6f.png
# /kaggle/input/samples/samples/cewnm.png
# /kaggle/input/samples/samples/55y2m.png
# /kaggle/input/samples/samples/8gecm.png
# /kaggle/input/samples/samples/myf82.png
# /kaggle/input/samples/samples/ypw3d.png
# /kaggle/input/samples/samples/m5meg.png
# /kaggle/input/samples/samples/nxx25.png
# /kaggle/input/samples/samples/4fp5g.png
# /kaggle/input/samples/samples/c6745.png
# /kaggle/input/samples/samples/xnnc3.png
# /kaggle/input/samples/samples/fg8n4.png
# /kaggle/input/samples/samples/pf5ng.png
# /kaggle/input/samples/samples/nn6w6.jpg
# /kaggle/input/samples/samples/pxne8.png
# /kaggle/input/samples/samples/wnpec.png
# /kaggle/input/samples/samples/d7en3.png
# /kaggle/input/samples/samples/42dw4.png
# /kaggle/input/samples/samples/bm3p8.png
# /kaggle/input/samples/samples/yy824.png
# /kaggle/input/samples/samples/33ng4.png
# /kaggle/input/samples/samples/664dn.png
# /kaggle/input/samples/samples/x3fwf.png
# /kaggle/input/samples/samples/bbymy.png
# /kaggle/input/samples/samples/n2c85.jpg
# /kaggle/input/samples/samples/xxbm5.png
# /kaggle/input/samples/samples/bxxfc.png
# /kaggle/input/samples/samples/3x5fm.png
# /kaggle/input/samples/samples/5nnff.png
# /kaggle/input/samples/samples/25w53.png
# /kaggle/input/samples/samples/8nbew.png
# /kaggle/input/samples/samples/mc8w2.png
# /kaggle/input/samples/samples/dn2ym.png
# /kaggle/input/samples/samples/nbp3e.png
# /kaggle/input/samples/samples/8db67.png
# /kaggle/input/samples/samples/gw53m.png
# /kaggle/input/samples/samples/7b4bm.png
# /kaggle/input/samples/samples/6n443.png
# /kaggle/input/samples/samples/3p4nn.png
# /kaggle/input/samples/samples/dbny3.png
# /kaggle/input/samples/samples/gewfy.png
# /kaggle/input/samples/samples/w8bnx.png
# /kaggle/input/samples/samples/6ng6w.png
# /kaggle/input/samples/samples/ewyg7.jpg
# /kaggle/input/samples/samples/63pxe.png
# /kaggle/input/samples/samples/c2yn8.png
# /kaggle/input/samples/samples/4dgf7.png
# /kaggle/input/samples/samples/yemy4.png
# /kaggle/input/samples/samples/8d2nd.png
# /kaggle/input/samples/samples/gc2wd.png
# /kaggle/input/samples/samples/m3588.png
# /kaggle/input/samples/samples/x74b2.png
# /kaggle/input/samples/samples/xnfx5.png
# /kaggle/input/samples/samples/y5dpp.png
# /kaggle/input/samples/samples/x347n.png
# /kaggle/input/samples/samples/ng2gw.png
# /kaggle/input/samples/samples/nb45d.png
# /kaggle/input/samples/samples/3nfdn.png
# /kaggle/input/samples/samples/wc2bd.png
# /kaggle/input/samples/samples/488de.png
# /kaggle/input/samples/samples/my84e.png
# /kaggle/input/samples/samples/cgcgb.png
# /kaggle/input/samples/samples/264m5.png
# /kaggle/input/samples/samples/ng46m.png
# /kaggle/input/samples/samples/yd755.png
# /kaggle/input/samples/samples/7xcyd.png
# /kaggle/input/samples/samples/c2g4d.png
# /kaggle/input/samples/samples/y33nm.png
# /kaggle/input/samples/samples/y7x8p.png
# /kaggle/input/samples/samples/24pew.png
# /kaggle/input/samples/samples/3mxdn.png
# /kaggle/input/samples/samples/n3m6x.png
# /kaggle/input/samples/samples/e43ym.png
# /kaggle/input/samples/samples/p2x7x.png
# /kaggle/input/samples/samples/573bn.png
# /kaggle/input/samples/samples/yyg5g.png
# /kaggle/input/samples/samples/cx3wg.png
# /kaggle/input/samples/samples/x8xnp.png
# /kaggle/input/samples/samples/3x325.png
# /kaggle/input/samples/samples/cdcb3.png
# /kaggle/input/samples/samples/pf4nb.png
# /kaggle/input/samples/samples/gxx2p.png
# /kaggle/input/samples/samples/g2577.png
# /kaggle/input/samples/samples/px8n8.png
# /kaggle/input/samples/samples/wddcp.png
# /kaggle/input/samples/samples/2nf26.png
# /kaggle/input/samples/samples/3den6.png
# /kaggle/input/samples/samples/387g2.png
# /kaggle/input/samples/samples/dxwcw.png
# /kaggle/input/samples/samples/dce8y.png
# /kaggle/input/samples/samples/mp7wp.png
# /kaggle/input/samples/samples/5bgp2.png
# /kaggle/input/samples/samples/2g7nm.png
# /kaggle/input/samples/samples/3ndxd.png
# /kaggle/input/samples/samples/4yc85.png
# /kaggle/input/samples/samples/mm3nn.png
# /kaggle/input/samples/samples/36nx4.png
# /kaggle/input/samples/samples/ncyx8.png
# /kaggle/input/samples/samples/nwfde.png
# /kaggle/input/samples/samples/2g783.png
# /kaggle/input/samples/samples/c5xne.png
# /kaggle/input/samples/samples/ffd6p.png
# /kaggle/input/samples/samples/nbmx7.png
# /kaggle/input/samples/samples/55w5c.png
# /kaggle/input/samples/samples/8d8ep.png
# /kaggle/input/samples/samples/gfxcc.png
# /kaggle/input/samples/samples/5bnd7.png
# /kaggle/input/samples/samples/d8dce.png
# /kaggle/input/samples/samples/gxxpf.png
# /kaggle/input/samples/samples/yfdn7.png
# /kaggle/input/samples/samples/w46ep.png
# /kaggle/input/samples/samples/pdyc8.png
# /kaggle/input/samples/samples/c43b4.png
# /kaggle/input/samples/samples/2n73f.png
# /kaggle/input/samples/samples/72m6f.png
# /kaggle/input/samples/samples/3bnyf.png
# /kaggle/input/samples/samples/c753e.png
# /kaggle/input/samples/samples/pmf5w.png
# /kaggle/input/samples/samples/2gyb6.png
# /kaggle/input/samples/samples/pg2yx.png
# /kaggle/input/samples/samples/77wp4.png
# /kaggle/input/samples/samples/f6bpw.jpg
# /kaggle/input/samples/samples/4egem.png
# /kaggle/input/samples/samples/mnef5.png
# /kaggle/input/samples/samples/7wyp4.png
# /kaggle/input/samples/samples/8gmnx.png
# /kaggle/input/samples/samples/b4d7c.png
# /kaggle/input/samples/samples/n3ffn.png
# /kaggle/input/samples/samples/c3572.png
# /kaggle/input/samples/samples/d2nbn.png
# /kaggle/input/samples/samples/2ycn8.png
# /kaggle/input/samples/samples/gd4mf.png
# /kaggle/input/samples/samples/cm6yb.png
# /kaggle/input/samples/samples/wnmyn.png
# /kaggle/input/samples/samples/xwx7d.png
# /kaggle/input/samples/samples/cpe63.png
# /kaggle/input/samples/samples/226md.png
# /kaggle/input/samples/samples/ypp8f.png
# /kaggle/input/samples/samples/7bb7b.png
# /kaggle/input/samples/samples/785n4.png
# /kaggle/input/samples/samples/mdxpn.png
# /kaggle/input/samples/samples/n2by7.png
# /kaggle/input/samples/samples/fp3wy.png
# /kaggle/input/samples/samples/467d5.png
# /kaggle/input/samples/samples/f22bn.png
# /kaggle/input/samples/samples/dpbyd.png
# /kaggle/input/samples/samples/3eny7.png
# /kaggle/input/samples/samples/6fn84.png
# /kaggle/input/samples/samples/d4ppy.png
# /kaggle/input/samples/samples/6pwcn.png
# /kaggle/input/samples/samples/d8xcn.png
# /kaggle/input/samples/samples/ngn26.png
# /kaggle/input/samples/samples/32cnn.png
# /kaggle/input/samples/samples/ymp7g.png
# /kaggle/input/samples/samples/5x7x5.png
# /kaggle/input/samples/samples/bwmee.png
# /kaggle/input/samples/samples/en4n4.png
# /kaggle/input/samples/samples/8xef7.png
# /kaggle/input/samples/samples/4cn7b.png
# /kaggle/input/samples/samples/x4pnp.png
# /kaggle/input/samples/samples/3bfnd.png
# /kaggle/input/samples/samples/fp5wn.png
# /kaggle/input/samples/samples/7pn5g.png
# /kaggle/input/samples/samples/nxn4f.png
# /kaggle/input/samples/samples/deep5.png
# /kaggle/input/samples/samples/px2xp.png
# /kaggle/input/samples/samples/5p3mm.png
# /kaggle/input/samples/samples/p4nm4.png
# /kaggle/input/samples/samples/4w76g.png
# /kaggle/input/samples/samples/5gcd3.png
# /kaggle/input/samples/samples/2en7g.png
# /kaggle/input/samples/samples/87nym.png
# /kaggle/input/samples/samples/de45x.png
# /kaggle/input/samples/samples/f35xp.png
# /kaggle/input/samples/samples/cdfen.png
# /kaggle/input/samples/samples/34fxm.png
# /kaggle/input/samples/samples/nmw46.png
# /kaggle/input/samples/samples/fxpw3.png
# /kaggle/input/samples/samples/m3b5p.png
# /kaggle/input/samples/samples/b26nd.png
# /kaggle/input/samples/samples/n464c.png
# /kaggle/input/samples/samples/44xe8.png
# /kaggle/input/samples/samples/m448b.png
# /kaggle/input/samples/samples/mpxfb.png
# /kaggle/input/samples/samples/mw5p2.png
# /kaggle/input/samples/samples/ppx77.png
# /kaggle/input/samples/samples/x6pdb.png
# /kaggle/input/samples/samples/3xng6.png
# /kaggle/input/samples/samples/wecfd.png
# /kaggle/input/samples/samples/6pfy4.png
# /kaggle/input/samples/samples/nnn5p.png
# /kaggle/input/samples/samples/d3c8y.png
# /kaggle/input/samples/samples/w2yp7.png
# /kaggle/input/samples/samples/nnp4e.png
# /kaggle/input/samples/samples/6p7gx.png
# /kaggle/input/samples/samples/dnne7.png
# /kaggle/input/samples/samples/nfg23.png
# /kaggle/input/samples/samples/b4ndb.jpg
# /kaggle/input/samples/samples/64b3p.png
# /kaggle/input/samples/samples/wfy5m.png
# /kaggle/input/samples/samples/2cgyx.png
# /kaggle/input/samples/samples/8cccc.png
# /kaggle/input/samples/samples/bp2d4.png
# /kaggle/input/samples/samples/4b2pw.png
# /kaggle/input/samples/samples/w4cdc.png
# /kaggle/input/samples/samples/2enf4.png
# /kaggle/input/samples/samples/yew6p.png
# /kaggle/input/samples/samples/6end3.png
# /kaggle/input/samples/samples/dn26n.png
# /kaggle/input/samples/samples/p5nce.png
# /kaggle/input/samples/samples/ennmm.png
# /kaggle/input/samples/samples/egxmp.png
# /kaggle/input/samples/samples/y2xg4.png
# /kaggle/input/samples/samples/f5cm2.png
# /kaggle/input/samples/samples/dmxp8.png
# /kaggle/input/samples/samples/24f6w.png
# /kaggle/input/samples/samples/dn5df.png
# /kaggle/input/samples/samples/gd8fb.png
# /kaggle/input/samples/samples/53wb8.png
# /kaggle/input/samples/samples/c2fb7.png
# /kaggle/input/samples/samples/geyn5.jpg
# /kaggle/input/samples/samples/ccf2w.png
# /kaggle/input/samples/samples/7cdge.png
# /kaggle/input/samples/samples/efe62.png
# /kaggle/input/samples/samples/g842c.png
# /kaggle/input/samples/samples/865wm.png
# /kaggle/input/samples/samples/ec6pm.png
# /kaggle/input/samples/samples/68x48.png
# /kaggle/input/samples/samples/ndecc.png
# /kaggle/input/samples/samples/cpc8c.png
# /kaggle/input/samples/samples/3wnd3.png
# /kaggle/input/samples/samples/yyn57.png
# /kaggle/input/samples/samples/ygenn.png
# /kaggle/input/samples/samples/f753f.png
# /kaggle/input/samples/samples/mwxwp.png
# /kaggle/input/samples/samples/bw5ym.png
# /kaggle/input/samples/samples/4d22m.png
# /kaggle/input/samples/samples/8e32m.png
# /kaggle/input/samples/samples/6f2yc.png
# /kaggle/input/samples/samples/33b22.png
# /kaggle/input/samples/samples/23n88.png
# /kaggle/input/samples/samples/ccn2x.png
# /kaggle/input/samples/samples/dy3cx.png
# /kaggle/input/samples/samples/ndg2b.png
# /kaggle/input/samples/samples/cndmc.jpg
# /kaggle/input/samples/samples/7xd5m.png
# /kaggle/input/samples/samples/pwmbn.png
# /kaggle/input/samples/samples/p8c24.png
# /kaggle/input/samples/samples/w2n7e.png
# /kaggle/input/samples/samples/f75cx.png
# /kaggle/input/samples/samples/5mfff.png
# /kaggle/input/samples/samples/y32yy.png
# /kaggle/input/samples/samples/5expp.png
# /kaggle/input/samples/samples/pgm2e.png
# /kaggle/input/samples/samples/n7dyb.png
# /kaggle/input/samples/samples/excmn.png
# /kaggle/input/samples/samples/pmg55.png
# /kaggle/input/samples/samples/cfp86.png
# /kaggle/input/samples/samples/2cegf.png
# /kaggle/input/samples/samples/m8m4x.png
# /kaggle/input/samples/samples/pcmcc.jpg
# /kaggle/input/samples/samples/ddnpf.png
# /kaggle/input/samples/samples/8c2wy.png
# /kaggle/input/samples/samples/edg3p.png
# /kaggle/input/samples/samples/ygfwe.png
# /kaggle/input/samples/samples/p2m6n.png
# /kaggle/input/samples/samples/w6pxy.png
# /kaggle/input/samples/samples/ewnx8.png
# /kaggle/input/samples/samples/2b827.png
# /kaggle/input/samples/samples/n6f4b.png
# /kaggle/input/samples/samples/2xc2n.png
# /kaggle/input/samples/samples/5dxnm.png
# /kaggle/input/samples/samples/2fxgd.png
# /kaggle/input/samples/samples/pn7pn.png
# /kaggle/input/samples/samples/e3cfe.jpg
# /kaggle/input/samples/samples/n5wbg.png
# /kaggle/input/samples/samples/n6nn2.png
# /kaggle/input/samples/samples/x8e8n.png
# /kaggle/input/samples/samples/56ncx.png
# /kaggle/input/samples/samples/gcfgp.png
# /kaggle/input/samples/samples/cffp4.png
# /kaggle/input/samples/samples/ddxpp.jpg
# /kaggle/input/samples/samples/dnmd8.png
# /kaggle/input/samples/samples/mn5c4.png
# /kaggle/input/samples/samples/f6ww8.png
# /kaggle/input/samples/samples/478nx.png
# /kaggle/input/samples/samples/6bnnm.png
# /kaggle/input/samples/samples/bnc5f.png
# /kaggle/input/samples/samples/g3dy6.png
# /kaggle/input/samples/samples/g7wxw.png
# /kaggle/input/samples/samples/5n732.png
# /kaggle/input/samples/samples/mb4en.png
# /kaggle/input/samples/samples/7pcd7.png
# /kaggle/input/samples/samples/37ep6.png
# /kaggle/input/samples/samples/7yf62.png
# /kaggle/input/samples/samples/pybee.png
# /kaggle/input/samples/samples/63824.png
# /kaggle/input/samples/samples/25p2m.png
# /kaggle/input/samples/samples/xdcn4.png
# /kaggle/input/samples/samples/gm2c2.png
# /kaggle/input/samples/samples/f85y3.png
# /kaggle/input/samples/samples/wye85.png
# /kaggle/input/samples/samples/gy5bf.png
# /kaggle/input/samples/samples/xbem6.png
# /kaggle/input/samples/samples/bc8nf.png
# /kaggle/input/samples/samples/6c3p5.png
# /kaggle/input/samples/samples/xemyg.png
# /kaggle/input/samples/samples/xp24p.png
# /kaggle/input/samples/samples/7fmcy.png
# /kaggle/input/samples/samples/f228n.png
# /kaggle/input/samples/samples/4fc36.png
# /kaggle/input/samples/samples/6cwxe.png
# /kaggle/input/samples/samples/25257.png
# /kaggle/input/samples/samples/8n2pg.png
# /kaggle/input/samples/samples/xmcym.png
# /kaggle/input/samples/samples/nbf8m.png
# /kaggle/input/samples/samples/76353.png
# /kaggle/input/samples/samples/43xfe.png
# /kaggle/input/samples/samples/5f3gf.png
# /kaggle/input/samples/samples/b84xc.png
# /kaggle/input/samples/samples/xfg65.png
# /kaggle/input/samples/samples/cdf77.png
# /kaggle/input/samples/samples/7e2y7.png
# /kaggle/input/samples/samples/w8f36.png
# /kaggle/input/samples/samples/74853.png
# /kaggle/input/samples/samples/w4cnn.png
# /kaggle/input/samples/samples/n7ebx.png
# /kaggle/input/samples/samples/xxw44.png
# /kaggle/input/samples/samples/p2ym2.png
# /kaggle/input/samples/samples/nxf2c.jpg
# /kaggle/input/samples/samples/bny23.png
# /kaggle/input/samples/samples/xfgxb.png
# /kaggle/input/samples/samples/nxxf8.png
# /kaggle/input/samples/samples/g2fnw.png
# /kaggle/input/samples/samples/f7cey.png
# /kaggle/input/samples/samples/4f8yp.png
# /kaggle/input/samples/samples/5wddw.png
# /kaggle/input/samples/samples/n8fp6.png
# /kaggle/input/samples/samples/65nmw.jpg
# /kaggle/input/samples/samples/befbd.png
# /kaggle/input/samples/samples/7gce6.png
# /kaggle/input/samples/samples/en32e.png
# /kaggle/input/samples/samples/bgd4m.png
# /kaggle/input/samples/samples/ggd7m.png
# /kaggle/input/samples/samples/3n2b4.png
# /kaggle/input/samples/samples/pdcp4.png
# /kaggle/input/samples/samples/gc83b.png
# /kaggle/input/samples/samples/36bc2.png
# /kaggle/input/samples/samples/by5y3.png
# /kaggle/input/samples/samples/x44n4.png
# /kaggle/input/samples/samples/b2g8e.png
# /kaggle/input/samples/samples/28x47.png
# /kaggle/input/samples/samples/8g4yp.png
# /kaggle/input/samples/samples/c6f8g.png
# /kaggle/input/samples/samples/3cpwb.png
# /kaggle/input/samples/samples/5nm6d.png
# /kaggle/input/samples/samples/3p67n.png
# /kaggle/input/samples/samples/78eec.png
# /kaggle/input/samples/samples/y5n6d.png
# /kaggle/input/samples/samples/neggn.png
# /kaggle/input/samples/samples/wf684.png
# /kaggle/input/samples/samples/nxc83.png
# /kaggle/input/samples/samples/6n6gg.png
# /kaggle/input/samples/samples/4w6mw.png
# /kaggle/input/samples/samples/d22n7.png
# /kaggle/input/samples/samples/nnf8b.png
# /kaggle/input/samples/samples/6n5fd.png
# /kaggle/input/samples/samples/6xpme.png
# /kaggle/input/samples/samples/f2m8n.png
# /kaggle/input/samples/samples/3g2w6.png
# /kaggle/input/samples/samples/dw3nn.png
# /kaggle/input/samples/samples/823p2.png
# /kaggle/input/samples/samples/646x8.png
# /kaggle/input/samples/samples/3pe4g.png
# /kaggle/input/samples/samples/cdmn8.png
# /kaggle/input/samples/samples/6dmx7.png
# /kaggle/input/samples/samples/pwn5e.png
# /kaggle/input/samples/samples/3nw7w.png
# /kaggle/input/samples/samples/mc35n.png
# /kaggle/input/samples/samples/832f3.png
# /kaggle/input/samples/samples/w52fn.png
# /kaggle/input/samples/samples/22d5n.png
# /kaggle/input/samples/samples/nngxc.png
# /kaggle/input/samples/samples/pg4bf.png
# /kaggle/input/samples/samples/nbwnn.png
# /kaggle/input/samples/samples/b3xpn.png
# /kaggle/input/samples/samples/nf8b8.png
# /kaggle/input/samples/samples/5n728.png
# /kaggle/input/samples/samples/g78gn.png
# /kaggle/input/samples/samples/xxney.png
# /kaggle/input/samples/samples/bgem5.png
# /kaggle/input/samples/samples/y4g3b.png
# /kaggle/input/samples/samples/cnwyc.png
# /kaggle/input/samples/samples/gnc3n.png
# /kaggle/input/samples/samples/mxyxw.png
# /kaggle/input/samples/samples/yw7ny.png
# /kaggle/input/samples/samples/e72cd.png
# /kaggle/input/samples/samples/fg7mg.png
# /kaggle/input/samples/samples/dc436.png
# /kaggle/input/samples/samples/7nnnx.png
# /kaggle/input/samples/samples/ep85x.png
# /kaggle/input/samples/samples/n4cpy.png
# /kaggle/input/samples/samples/gp7c5.png
# /kaggle/input/samples/samples/378e5.png
# /kaggle/input/samples/samples/p24gn.png
# /kaggle/input/samples/samples/m457d.png
# /kaggle/input/samples/samples/xfn6n.png
# /kaggle/input/samples/samples/yd3m3.png
# /kaggle/input/samples/samples/b6f2p.png
# /kaggle/input/samples/samples/e46yw.png
# /kaggle/input/samples/samples/efgx5.png
# /kaggle/input/samples/samples/cy3nw.png
# /kaggle/input/samples/samples/7dgc2.png
# /kaggle/input/samples/samples/5nxnn.png
# /kaggle/input/samples/samples/ny5dp.png
# /kaggle/input/samples/samples/xe6eb.png
# /kaggle/input/samples/samples/6e554.png
# /kaggle/input/samples/samples/d236n.png
# /kaggle/input/samples/samples/w6yne.png
# /kaggle/input/samples/samples/xf5g7.png
# /kaggle/input/samples/samples/74eyg.png
# /kaggle/input/samples/samples/mgdwb.png
# /kaggle/input/samples/samples/e5n66.png
# /kaggle/input/samples/samples/c4bny.png
# /kaggle/input/samples/samples/efb3f.png
# /kaggle/input/samples/samples/yg5bb.png
# /kaggle/input/samples/samples/cen55.png
# /kaggle/input/samples/samples/mx8bb.png
# /kaggle/input/samples/samples/xnn4d.png
# /kaggle/input/samples/samples/de7f8.png
# /kaggle/input/samples/samples/6mege.png
# /kaggle/input/samples/samples/368y5.png
# /kaggle/input/samples/samples/4nc37.png
# /kaggle/input/samples/samples/7gnge.png
# /kaggle/input/samples/samples/4gycb.png
# /kaggle/input/samples/samples/65ebm.png
# /kaggle/input/samples/samples/p4pde.png
# /kaggle/input/samples/samples/c7nn8.png
# /kaggle/input/samples/samples/m6n4x.png
# /kaggle/input/samples/samples/ddpyb.png
# /kaggle/input/samples/samples/n3x4c.png
# /kaggle/input/samples/samples/8d4wm.png
# /kaggle/input/samples/samples/m8gmx.png
# /kaggle/input/samples/samples/een23.png
# /kaggle/input/samples/samples/42nxy.png
# /kaggle/input/samples/samples/d6fcn.png
# /kaggle/input/samples/samples/8bbw8.png
# /kaggle/input/samples/samples/g55b4.png
# /kaggle/input/samples/samples/5p8fm.png
# /kaggle/input/samples/samples/88y52.png
# /kaggle/input/samples/samples/8ypdn.png
# /kaggle/input/samples/samples/4dw3w.png
# /kaggle/input/samples/samples/ycmcw.png
# /kaggle/input/samples/samples/pgmn2.png
# /kaggle/input/samples/samples/nfbg8.png
# /kaggle/input/samples/samples/245y5.png
# /kaggle/input/samples/samples/ne325.png
# /kaggle/input/samples/samples/58b5m.png
# /kaggle/input/samples/samples/wyc25.png
# /kaggle/input/samples/samples/nnfx3.png
# /kaggle/input/samples/samples/5bb66.png
# /kaggle/input/samples/samples/wm47f.png
# /kaggle/input/samples/samples/e6m6p.png
# /kaggle/input/samples/samples/emwpn.png
# /kaggle/input/samples/samples/f364x.png
# /kaggle/input/samples/samples/57wdp.png
# /kaggle/input/samples/samples/gegw4.png
# /kaggle/input/samples/samples/xngxc.png
# /kaggle/input/samples/samples/yge7c.jpg
# /kaggle/input/samples/samples/xnd3y.png
# /kaggle/input/samples/samples/xcmbp.png
# /kaggle/input/samples/samples/85dxn.png
# /kaggle/input/samples/samples/cwmny.png
# /kaggle/input/samples/samples/8nn73.png
# /kaggle/input/samples/samples/43gey.png
# /kaggle/input/samples/samples/f4wfn.png
# /kaggle/input/samples/samples/c4mcm.png
# /kaggle/input/samples/samples/yw8y5.jpg
# /kaggle/input/samples/samples/n8ydd.png
# /kaggle/input/samples/samples/yf347.png
# /kaggle/input/samples/samples/377xx.png
# /kaggle/input/samples/samples/2npg6.png
# /kaggle/input/samples/samples/b43nw.png
# /kaggle/input/samples/samples/nm248.png
# /kaggle/input/samples/samples/fncnb.png
# /kaggle/input/samples/samples/58pnp.png
# /kaggle/input/samples/samples/43mn5.png
# /kaggle/input/samples/samples/xgcxy.png
# /kaggle/input/samples/samples/mmy5n.png
# /kaggle/input/samples/samples/nbfx5.png
# /kaggle/input/samples/samples/f83pn.png
# /kaggle/input/samples/samples/6c3n6.png
# /kaggle/input/samples/samples/dbex3.png
# /kaggle/input/samples/samples/6ydyp.png
# /kaggle/input/samples/samples/ppwyd.png
# /kaggle/input/samples/samples/64m82.png
# /kaggle/input/samples/samples/c8n8c.png
# /kaggle/input/samples/samples/dyxnc.png
# /kaggle/input/samples/samples/36w25.png
# /kaggle/input/samples/samples/77n6g.png
# /kaggle/input/samples/samples/be3bp.png
# /kaggle/input/samples/samples/5ep3n.png
# /kaggle/input/samples/samples/pe4xn.png
# /kaggle/input/samples/samples/nn4wx.png
# /kaggle/input/samples/samples/5np4m.png
# /kaggle/input/samples/samples/7dwx4.png
# /kaggle/input/samples/samples/gymmn.png
# /kaggle/input/samples/samples/xdn65.png
# /kaggle/input/samples/samples/33n73.png
# /kaggle/input/samples/samples/cg5dd.png
# /kaggle/input/samples/samples/8wy7d.png
# /kaggle/input/samples/samples/bgxcd.jpg
# /kaggle/input/samples/samples/gy433.png
# /kaggle/input/samples/samples/p5g5m.png
# /kaggle/input/samples/samples/2wx73.png
# /kaggle/input/samples/samples/bpwd7.png
# /kaggle/input/samples/samples/4nnf3.png
# /kaggle/input/samples/samples/e4gd7.png
# /kaggle/input/samples/samples/x38fn.png
# /kaggle/input/samples/samples/x7422.png
# /kaggle/input/samples/samples/x5nyn.png
# /kaggle/input/samples/samples/ddcdd.png
# /kaggle/input/samples/samples/cd4eg.png
# /kaggle/input/samples/samples/yf28d.png
# /kaggle/input/samples/samples/x2cnn.png
# /kaggle/input/samples/samples/253dc.png
# /kaggle/input/samples/samples/6e6pn.png
# /kaggle/input/samples/samples/5ng6e.png
# /kaggle/input/samples/samples/8cm46.png
# /kaggle/input/samples/samples/b35f6.png
# /kaggle/input/samples/samples/mmc5n.png
# /kaggle/input/samples/samples/7cgym.png
# /kaggle/input/samples/samples/66wp5.png
# /kaggle/input/samples/samples/3dgmf.png
# /kaggle/input/samples/samples/nwncn.png
# /kaggle/input/samples/samples/n5w5g.png
# /kaggle/input/samples/samples/5yxgp.png
# /kaggle/input/samples/samples/bmxpe.png
# /kaggle/input/samples/samples/wdww8.png
# /kaggle/input/samples/samples/b28g8.png
# /kaggle/input/samples/samples/d2n8x.jpg
# /kaggle/input/samples/samples/6gnm3.png
# /kaggle/input/samples/samples/yf424.png
# /kaggle/input/samples/samples/46mbm.png
# /kaggle/input/samples/samples/4c8n8.png
# /kaggle/input/samples/samples/e76n4.png
# /kaggle/input/samples/samples/n265y.png
# /kaggle/input/samples/samples/65m85.png
# /kaggle/input/samples/samples/ef4mn.png
# /kaggle/input/samples/samples/w75w8.png
# /kaggle/input/samples/samples/cfc56.png
# /kaggle/input/samples/samples/wxy4n.png
# /kaggle/input/samples/samples/e2mg2.png
# /kaggle/input/samples/samples/cb8cf.png
# /kaggle/input/samples/samples/8n4n8.png
# /kaggle/input/samples/samples/pp546.png

# %%
# Distribution graphs (histogram/bar graph) of column data
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 50]] # For displaying purposes, pick columns that have between 1 and 50 unique values
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = (nCol + nGraphPerRow - 1) / nGraphPerRow
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.show()

# %%
# Correlation matrix
def plotCorrelationMatrix(df, graphWidth):
    filename = df.dataframeName
    df = df.dropna('columns') # drop columns with NaN
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    if df.shape[1] < 2:
        print(f'No correlation plots shown: The number of non-NaN or constant columns ({df.shape[1]}) is less than 2')
        return
    corr = df.corr()
    plt.figure(num=None, figsize=(graphWidth, graphWidth), dpi=80, facecolor='w', edgecolor='k')
    corrMat = plt.matshow(corr, fignum = 1)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
    plt.yticks(range(len(corr.columns)), corr.columns)
    plt.gca().xaxis.tick_bottom()
    plt.colorbar(corrMat)
    plt.title(f'Correlation Matrix for {filename}', fontsize=15)
    plt.show()

# %%
# Scatter and density plots
def plotScatterMatrix(df, plotSize, textSize):
    df = df.select_dtypes(include =[np.number]) # keep only numerical columns
    # Remove rows and columns that would lead to df being singular
    df = df.dropna('columns')
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    columnNames = list(df)
    if len(columnNames) > 10: # reduce the number of columns for matrix inversion of kernel density plots
        columnNames = columnNames[:10]
    df = df[columnNames]
    ax = pd.plotting.scatter_matrix(df, alpha=0.75, figsize=[plotSize, plotSize], diagonal='kde')
    corrs = df.corr().values
    for i, j in zip(*plt.np.triu_indices_from(ax, k = 1)):
        ax[i, j].annotate('Corr. coef = %.3f' % corrs[i, j], (0.8, 0.2), xycoords='axes fraction', ha='center', va='center', size=textSize)
    plt.suptitle('Scatter and Density Plot')
    plt.show()
